# %%
import pandas as pd

# %%
df = pd.read_excel('BD COFECI - sem analises.xlsx')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                 Timestamp  \
# 0 2024-01-22 20:56:16.839
# 1 2024-01-17 12:27:34.853
# 2 2024-01-29 16:35:05.561
# 3 2024-01-22 14:23:37.423
# 4 2024-01-31 19:30:02.520
#
#   Estamos realizando uma pesquisa para conhecer o perfil dos corretores de imóveis, hábitos e outras características. Você concorda em responder um questionário, compartilhando conosco suas informações pessoais tais como, gênero e renda?\n \nSendo certo que e  \
# 0                                                Sim
# 1                                                Sim
# 2                                                Sim
# 3                                                Sim
# 4                                                Sim
#
#             Nome Entrevistador Nome Entrevistado\n\n(pegar Listagem)  \
# 0    Bruna Correia de Carvalho        FREDERICO FIGUEIREDO FERNANDES
# 1  Anadia Francisco Nascimento  MANOEL PINTO RODRIGUES DA COSTA NETO
# ...

# %%
try:
    df_pergs = pd.read_csv('cofeci.csv')
except Exception as e:
    print(e)
# Out:
# Error tokenizing data. C error: Expected 8 fields in line 28, saw 10

# %%
df_pergs.head()
# Out:
#    Unnamed: 0                   PERG.1 PERG.2                       PERG.3  \
# 0           0  2024-01-22 20:56:16.839    Sim    Bruna Correia de Carvalho
# 1           1  2024-01-17 12:27:34.853    Sim  Anadia Francisco Nascimento
# 2           2  2024-01-29 16:35:05.561    Sim    Bruna Correia de Carvalho
# 3           3  2024-01-22 14:23:37.423    Sim    Bruna Correia de Carvalho
# 4           4  2024-01-31 19:30:02.520    Sim         Patrícia Silva Costa
#
#                                  PERG.4    PERG.5               PERG.6  \
# 0        FREDERICO FIGUEIREDO FERNANDES        57           Bahia (BA)
# 1  MANOEL PINTO RODRIGUES DA COSTA NETO        61           Bahia (BA)
# 2                   WESLLEY CINTRA LARA        39  Espírito Santo (ES)
# 3   DOMINIQUE MONTEIRO CAVALCANTE SALES        42         Alagoas (AL)
# 4          JULIO CESAR PEREIRA DA SILVA  46 Anos         Maranhão (MA)
#
#      PERG.7       PERG.8     PERG.9              PERG.10 PERG.11    PERG.12  \
# ...

# %%
df_pergs["PERG.17"].value_counts()
# Out:
# Não                                                                51
# ADM                                                                32
# Direito                                                            32
# Administração                                                      32
# ADMINISTRAÇÃO.                                                     26
# DIREITO                                                            23
# DIREITO                                                            22
# ADMINISTRAÇÃO                                                      20
# Administração                                                      18
# ADMINISTRAÇÃO                                                      16
# Direito                                                            15
# DIREITO.                                                            9
# PEDAGOGIA                                                           8
# ...

# %%
pd.set_option('display.max_rows', None)
df_pergs.isna().sum()
# Out:
# Unnamed: 0       0
# PERG.1           0
# PERG.2           0
# PERG.3           0
# PERG.4           6
# PERG.5          35
# PERG.6           0
# PERG.7           0
# PERG.8           0
# PERG.9           9
# PERG.10         17
# PERG.11         80
# PERG.12        364
# PERG.13         26
# PERG.14          0
# PERG.15         20
# PERG.16         24
# PERG.17        430
# PERG.18          0
# PERG.19        887
# PERG.20       1061
# PERG.21        996
# PERG.22       1211
# PERG.23         20
# PERG.24         29
# PERG.25         59
# PERG.26         21
# PERG.27         12
# PERG.28         20
# PERG.29         10
# PERG.30         52
# PERG.31         24
# PERG.32         35
# PERG.33         28
# PERG.34         12
# PERG.35         21
# PERG.36         14
# PERG.37          0
# PERG.38         15
# PERG.39         17
# PERG.40         16
# PERG.41         12
# PERG.42         24
# PERG.43         60
# PERG.44        205
# PERG.45         43
# PERG.46          0
# ...
